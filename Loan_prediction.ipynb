# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan_approval_dataset.csv')

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
for col in df.columns:
    df.rename(columns={col:col.lstrip()} , inplace=True)

# %%
df['education'] = df['education'].map({' Graduate':1 , ' Not Graduate':0 })
df['self_employed'] = df['self_employed'].map({' No':0 , ' Yes':1})
df['loan_status'] = df['loan_status'].map({' Approved':1 , ' Rejected':0})

# %%
# from sklearn.preprocessing import StandardScaler

# %%
# cols = ['income_annum' , 'loan_amount'  , 'loan_term' , 'cibil_score' , 'residential_assets_value' , 'commercial_assets_value' , 'luxury_assets_value' , 'bank_asset_value'  ]

# %%
# scaler = StandardScaler()
# df[cols] = scaler.fit_transform(df[cols])

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['loan_id' , 'loan_status' , 'no_of_dependents' ,'education' , 'self_employed' ] , axis=1)
y=df['loan_status']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score ,classification_report  , confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
model = DecisionTreeClassifier()
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test , y_pred)
report = classification_report(y_test , y_pred)
print([accuracy])
print(report)
# Out:
# [0.9754098360655737]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       318
#            1       0.98      0.98      0.98       536
#
#     accuracy                           0.98       854
#    macro avg       0.97      0.97      0.97       854
# weighted avg       0.98      0.98      0.98       854

# %%
from joblib import dump , load

# %%
dump(model , 'loan_approval_prediction.joblib')
# Out:
# ['loan_approval_prediction.joblib']

# %%
x
# Out:
#       income_annum  loan_amount  loan_term  cibil_score  \
# 0          9600000     29900000         12          778
# 1          4100000     12200000          8          417
# 2          9100000     29700000         20          506
# 3          8200000     30700000          8          467
# 4          9800000     24200000         20          382
# ...            ...          ...        ...          ...
# 4264       1000000      2300000         12          317
# 4265       3300000     11300000         20          559
# 4266       6500000     23900000         18          457
# 4267       4100000     12800000          8          780
# 4268       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                      2400000                 17600000             22700000
# 1                      2700000                  2200000              8800000
# ...

# %%
# dump(scaler , 'scaler.joblib')

# %%
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          1              0       9600000
# 1           2                 0          0              1       4100000
# 2           3                 3          1              0       9100000
# 3           4                 3          1              0       8200000
# 4           5                 5          0              1       9800000
# ...       ...               ...        ...            ...           ...
# 4264     4265                 5          1              1       1000000
# 4265     4266                 0          0              1       3300000
# 4266     4267                 2          0              0       6500000
# 4267     4268                 1          0              0       4100000
# 4268     4269                 1          1              0       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# ...

# %%
x
# Out:
#       income_annum  loan_amount  loan_term  cibil_score  \
# 0          9600000     29900000         12          778
# 1          4100000     12200000          8          417
# 2          9100000     29700000         20          506
# 3          8200000     30700000          8          467
# 4          9800000     24200000         20          382
# ...            ...          ...        ...          ...
# 4264       1000000      2300000         12          317
# 4265       3300000     11300000         20          559
# 4266       6500000     23900000         18          457
# 4267       4100000     12800000          8          780
# 4268       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                      2400000                 17600000             22700000
# 1                      2700000                  2200000              8800000
# ...

# %%
model.predict(np.array([-0.7,-0.7,-0.7,-0.7,-0.7,-0.7,-0.7,-0.7]).reshape(1 , -1))
# Out:
# array([0])
