# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan_approval_dataset.csv')

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
df[' loan_status']
# Out:
# 0        Approved
# 1        Rejected
# 2        Rejected
# 3        Rejected
# 4        Rejected
#           ...
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved
# Name:  loan_status, Length: 4269, dtype: object

# %%
sns.countplot(data=df[' loan_status'])
# Out:
# <Axes: xlabel='count', ylabel=' loan_status'>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(y=df[' income_annum'] , x=df[' loan_status'] , kde=True)
# Out:
# <Axes: xlabel=' loan_status', ylabel=' income_annum'>

# %%
sns.boxenplot(x=df[' income_annum'] , y=df[' loan_status'])
# Out:
# <Axes: xlabel=' income_annum', ylabel=' loan_status'>

# %%
sns.boxenplot(x=df[' bank_asset_value'] , y=df[' loan_status'])
# Out:
# <Axes: xlabel=' bank_asset_value', ylabel=' loan_status'>

# %%
sns.boxenplot(x=df[' cibil_score'] , y=df[' loan_status'])
# Out:
# <Axes: xlabel=' cibil_score', ylabel=' loan_status'>

# %%
sns.boxenplot(x=df[' commercial_assets_value'] , y=df[' loan_status'])
# Out:
# <Axes: xlabel=' commercial_assets_value', ylabel=' loan_status'>

# %%
sns.boxenplot(x=df[' loan_amount'] , y=df[' loan_status'])
# Out:
# <Axes: xlabel=' loan_amount', ylabel=' loan_status'>

# %%
sns.boxenplot(x=df[' loan_term'] , y=df[' loan_status'])
# Out:
# <Axes: xlabel=' loan_term', ylabel=' loan_status'>

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
for col in df.columns:
    df.rename(columns={col:col.lstrip()} , inplace=True)

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# ...

# %%
df['education'] = df['education'].map({' Graduate':1 , ' Not Graduate':0 })

# %%
df['education']
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 4264    1
# 4265    0
# 4266    0
# 4267    0
# 4268    1
# Name: education, Length: 4269, dtype: int64

# %%
df['self_employed'] = df['self_employed'].map({' No':0 , ' Yes':1})
df['self_employed']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 4264    1
# 4265    1
# 4266    0
# 4267    0
# 4268    0
# Name: self_employed, Length: 4269, dtype: int64

# %%
df['loan_status'] = df['loan_status'].map({' Approved':1 , ' Rejected':0})
df['loan_status']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   int64
#  3   self_employed             4269 non-null   int64
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   int64
# dtypes: int64(13)
# memory usage: 433.7 KB

# %%
df.corr()
# Out:
#                            loan_id  no_of_dependents  education  \
# loan_id                   1.000000          0.005326   0.015536
# no_of_dependents          0.005326          1.000000   0.002697
# education                 0.015536          0.002697   1.000000
# self_employed             0.001745          0.000765  -0.023224
# income_annum              0.012592          0.007266   0.011625
# loan_amount               0.008170         -0.003366   0.010631
# loan_term                 0.009809         -0.020111  -0.008417
# cibil_score               0.016323         -0.009998  -0.004649
# residential_assets_value  0.020936          0.007376   0.010930
# commercial_assets_value   0.018595         -0.001531  -0.006763
# luxury_assets_value      -0.000862          0.002817   0.012471
# bank_asset_value          0.010765          0.011163   0.009424
# loan_status               0.017685         -0.018114   0.004918
#
# ...

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0        1                 2          1              0       9600000
# 1        2                 0          0              1       4100000
# 2        3                 3          1              0       9100000
# 3        4                 3          1              0       8200000
# 4        5                 5          0              1       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value  loan_status
# 0                 17600000             22700000           8000000            1
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
cols = ['no_of_dependents' , 'income_annum' , 'loan_amount'  , 'loan_term' , 'cibil_score' , 'residential_assets_value' , 'commercial_assets_value' , 'luxury_assets_value' , 'bank_asset_value'  ]

# %%
scaler = StandardScaler()

# %%
df[cols] = scaler.fit_transform(df[cols])

# %%
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1         -0.294102          1              0      1.617979
# 1           2         -1.473548          0              1     -0.341750
# 2           3          0.295621          1              0      1.439822
# 3           4          0.295621          1              0      1.119139
# 4           5          1.475067          0              1      1.689242
# ...       ...               ...        ...            ...           ...
# 4264     4265          1.475067          1              1     -1.446324
# 4265     4266         -1.473548          0              1     -0.626801
# 4266     4267         -0.294102          0              0      0.513405
# 4267     4268         -0.883825          0              0     -0.341750
# 4268     4269         -0.883825          1              0      1.475453
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df.corr()
# Out:
#                            loan_id  no_of_dependents  education  \
# loan_id                   1.000000          0.005326   0.015536
# no_of_dependents          0.005326          1.000000   0.002697
# education                 0.015536          0.002697   1.000000
# self_employed             0.001745          0.000765  -0.023224
# income_annum              0.012592          0.007266   0.011625
# loan_amount               0.008170         -0.003366   0.010631
# loan_term                 0.009809         -0.020111  -0.008417
# cibil_score               0.016323         -0.009998  -0.004649
# residential_assets_value  0.020936          0.007376   0.010930
# commercial_assets_value   0.018595         -0.001531  -0.006763
# luxury_assets_value      -0.000862          0.002817   0.012471
# bank_asset_value          0.010765          0.011163   0.009424
# loan_status               0.017685         -0.018114   0.004918
#
# ...

# %%
x = df.drop(['loan_id' , 'loan_status' , 'no_of_dependents' ,'education' , 'self_employed' ] , axis=1)
y=df['loan_status']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score ,classification_report  , confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
models = {
    "Logistic Reg":LogisticRegression(),
    "KNN":KNeighborsClassifier(n_neighbors=5),
    "Naive_Bayes" : GaussianNB(),
    "Dtree":DecisionTreeClassifier(), 
    "SVM": SVC(kernel='rbf')
}

# %%
result = []

# %%
for model_name , model in models.items():
    model.fit(x_train , y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test , y_pred)
    report = classification_report(y_test , y_pred)
    result.append({model_name : [accuracy]})
    print(model_name , report)
# Out:
# Logistic Reg               precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50       318
#            1       0.72      0.95      0.81       536
#
#     accuracy                           0.73       854
#    macro avg       0.76      0.66      0.66       854
# weighted avg       0.75      0.73      0.70       854
#
# KNN               precision    recall  f1-score   support
#
#            0       0.41      0.29      0.34       318
#            1       0.64      0.75      0.69       536
#
#     accuracy                           0.58       854
#    macro avg       0.52      0.52      0.52       854
# weighted avg       0.55      0.58      0.56       854
#
# Naive_Bayes               precision    recall  f1-score   support
#
#            0       0.92      0.42      0.58       318
#            1       0.74      0.98      0.84       536
#
#     accuracy                           0.77       854
#    macro avg       0.83      0.70      0.71       854
# ...

# %%
result
# Out:
# [{'Logistic Reg': [0.7295081967213115]},
#  {'KNN': [0.5784543325526932]},
#  {'Naive_Bayes': [0.7716627634660421]},
#  {'Dtree': [0.9742388758782201]},
#  {'SVM': [0.6276346604215457]}]

# %%
result
# Out:
# [{'Logistic Reg': [0.905152224824356]},
#  {'KNN': [0.9192037470725996]},
#  {'Naive_Bayes': [0.9391100702576113]},
#  {'Dtree': [0.977751756440281]},
#  {'SVM': [0.9379391100702577]}]

# %%
result
# Out:
# [{'Logistic Reg': [0.9110070257611241]},
#  {'KNN': [0.9238875878220141]},
#  {'Naive_Bayes': [0.9379391100702577]},
#  {'Dtree': [0.9625292740046838]},
#  {'SVM': [0.9344262295081968]}]

# %%
result
# Out:
# [{'Logistic Reg': [0.905152224824356]},
#  {'KNN': [0.9192037470725996]},
#  {'Naive_Bayes': [0.9391100702576113]},
#  {'Dtree': [0.9765807962529274]},
#  {'SVM': [0.9379391100702577]}]
